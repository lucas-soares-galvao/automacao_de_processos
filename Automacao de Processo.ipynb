# %% [markdown]
# ### Passo 1 - Importar Arquivos e Bibliotecas

# %%
import pandas as pd
from pathlib import Path
import win32com.client as win32

vendas_df = pd.read_excel(r"Bases de Dados/Vendas.xlsx")
lojas_df = pd.read_csv(r"Bases de Dados/Lojas.csv", sep=";", encoding="latin-1")
emails_df = pd.read_excel(r"Bases de Dados/Emails.xlsx")

# %% [markdown]
# ### Passo 2 - Definir Criar uma Tabela para cada Loja e Definir o dia do Indicador

# %%
display(vendas_df)
# Out:
#         Código Venda       Data  ID Loja           Produto  Quantidade
# 0                  1 2019-01-01        1    Sapato Estampa           1  \
# 1                  1 2019-01-01        1          Camiseta           2
# 2                  1 2019-01-01        1     Sapato Xadrez           1
# 3                  2 2019-01-02        3           Relógio           3
# 4                  2 2019-01-02        3      Chinelo Liso           1
# ...              ...        ...      ...               ...         ...
# 100994         69996 2019-12-26       17    Short Listrado           2
# 100995         69996 2019-12-26       17           Mochila           4
# 100996         69996 2019-12-26       17  Pulseira Estampa           1
# 100997         69997 2019-12-26       11   Camisa Listrado           1
# 100998         69997 2019-12-26       11       Short Linho           2
#
#         Valor Unitário  Valor Final
# 0                  358          358
# 1                  180          360
# 2                  368          368
# 3                  200          600
# 4                   71           71
# ...                ...          ...
# 100994             102          204
# 100995             270         1080
# 100996              87           87
# 100997             108          108
# 100998             133          266
#
# [100999 rows x 7 columns]

# %%
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100999 entries, 0 to 100998
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Código Venda    100999 non-null  int64
#  1   Data            100999 non-null  datetime64[ns]
#  2   ID Loja         100999 non-null  int64
#  3   Produto         100999 non-null  object
#  4   Quantidade      100999 non-null  int64
#  5   Valor Unitário  100999 non-null  int64
#  6   Valor Final     100999 non-null  int64
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 5.4+ MB

# %%
# Mesclando vendas_df com lojas_df para trazer o nome da loja
vendas_df = vendas_df.merge(lojas_df, on = "ID Loja")
display(vendas_df)
# Out:
#         Código Venda       Data  ID Loja                 Produto  Quantidade
# 0                  1 2019-01-01        1          Sapato Estampa           1  \
# 1                  1 2019-01-01        1                Camiseta           2
# 2                  1 2019-01-01        1           Sapato Xadrez           1
# 3                 21 2019-01-02        1  Camisa Gola V Listrado           2
# 4                 34 2019-01-02        1         Sapato Listrado           1
# ...              ...        ...      ...                     ...         ...
# 100994         69846 2019-12-25        8           Short Estampa           2
# 100995         69846 2019-12-25        8           Tênis Estampa           5
# 100996         69850 2019-12-25        8           Calça Estampa           4
# 100997         69972 2019-12-26        8              Terno Liso           3
# 100998         69972 2019-12-26        8          Sapato Estampa           5
#
#         Valor Unitário  Valor Final                Loja
# 0                  358          358  Iguatemi Esplanada
# 1                  180          360  Iguatemi Esplanada
# 2                  368          368  Iguatemi Esplanada
# 3                  116          232  Iguatemi Esplanada
# 4                  363          363  Iguatemi Esplanada
# ...                ...          ...                 ...
# 100994              96          192   Salvador Shopping
# 100995             256         1280   Salvador Shopping
# 100996             177          708   Salvador Shopping
# 100997             720         2160   Salvador Shopping
# 100998             358         1790   Salvador Shopping
#
# [100999 rows x 8 columns]

# %%
# Criar uma tabela pra cada loja
dicionario_loja = {}
# Para cada loja na tabela de lojas (para não pegar valor repetido) 
for loja in lojas_df["Loja"]:
    print(loja)
    # Filtra o dataframe da loja e cria um dicionário pra ela
    dicionario_loja[loja] = vendas_df[vendas_df["Loja"] == loja]
# Out:
# Iguatemi Esplanada
# Shopping Midway Mall
# Norte Shopping
# Shopping Iguatemi Fortaleza
# Shopping União de Osasco
# Shopping Center Interlagos
# Rio Mar Recife
# Salvador Shopping
# Rio Mar Shopping Fortaleza
# Shopping Center Leste Aricanduva
# Ribeirão Shopping
# Shopping Morumbi
# Parque Dom Pedro Shopping
# Bourbon Shopping SP
# Palladium Shopping Curitiba
# Passei das Águas Shopping
# Center Shopping Uberlândia
# Shopping Recife
# Shopping Vila Velha
# Shopping SP Market
# Shopping Eldorado
# Shopping Ibirapuera
# Novo Shopping Ribeirão Preto
# Iguatemi Campinas
# Shopping Barra

# %%
display(dicionario_loja)
# Out:
# {'Iguatemi Esplanada':       Código Venda       Data  ID Loja                 Produto  Quantidade
#  0                1 2019-01-01        1          Sapato Estampa           1  \
#  1                1 2019-01-01        1                Camiseta           2
#  2                1 2019-01-01        1           Sapato Xadrez           1
#  3               21 2019-01-02        1  Camisa Gola V Listrado           2
#  4               34 2019-01-02        1         Sapato Listrado           1
#  ...            ...        ...      ...                     ...         ...
#  3975         69899 2019-12-25        1           Sapato Xadrez           4
#  3976         69903 2019-12-25        1              Terno Liso           5
#  3977         69928 2019-12-25        1                    Meia           1
#  3978         69944 2019-12-25        1            Gorro Xadrez           5
#  3979         69944 2019-12-25        1           Sapato Xadrez           2
#
#        Valor Unitário  Valor Final                Loja
#  0                358          358  Iguatemi Esplanada
#  1                180          360  Iguatemi Esplanada
#  2                368          368  Iguatemi Esplanada
#  3                116          232  Iguatemi Esplanada
#  4                363          363  Iguatemi Esplanada
#  ...              ...          ...                 ...
#  3975             368         1472  Iguatemi Esplanada
#  3976             720         3600  Iguatemi Esplanada
#  3977              30           30  Iguatemi Esplanada
#  3978              85          425  Iguatemi Esplanada
#  3979             368          736  Iguatemi Esplanada
#
#  [3980 rows x 8 columns],
#  'Shopping Midway Mall':        Código Venda       Data  ID Loja        Produto  Quantidade
#  36382            12 2019-01-02        2   Short Xadrez           4  \
#  36383            12 2019-01-02        2     Sunga Liso           2
#  36384            33 2019-01-02        2         Camisa           1
#  36385            33 2019-01-02        2    Meia Xadrez           3
#  36386            48 2019-01-02        2    Cueca Linho           2
#  ...             ...        ...      ...            ...         ...
#  40214         69914 2019-12-25        2     Short Liso           2
#  40215         69914 2019-12-25        2          Cinto           5
#  40216         69919 2019-12-25        2   Cinto Xadrez           3
#  40217         69929 2019-12-25        2  Meia Listrado           2
#  40218         69994 2019-12-26        2          Calça           1
#
#         Valor Unitário  Valor Final                  Loja
#  36382             100          400  Shopping Midway Mall
#  36383             114          228  Shopping Midway Mall
#  36384             100          100  Shopping Midway Mall
#  36385              41          123  Shopping Midway Mall
#  36386              93          186  Shopping Midway Mall
#  ...               ...          ...                   ...
#  40214             108          216  Shopping Midway Mall
#  40215             200         1000  Shopping Midway Mall
#  40216             215          645  Shopping Midway Mall
#  40217              37           74  Shopping Midway Mall
#  40218             170          170  Shopping Midway Mall
#
#  [3837 rows x 8 columns],
#  'Norte Shopping':       Código Venda       Data  ID Loja                 Produto  Quantidade
#  3980             2 2019-01-02        3                 Relógio           3  \
#  3981             2 2019-01-02        3            Chinelo Liso           1
#  3982             7 2019-01-02        3  Camisa Gola V Listrado           1
#  3983             7 2019-01-02        3             Camisa Liso           1
#  3984            73 2019-01-02        3            Cueca Xadrez           5
#  ...            ...        ...      ...                     ...         ...
#  8154         69888 2019-12-25        3             Tênis Linho           1
#  8155         69916 2019-12-25        3                   Terno           2
#  8156         69962 2019-12-25        3              Meia Linho           2
#  8157         69976 2019-12-26        3            Tênis Xadrez           1
#  8158         69976 2019-12-26        3                  Casaco           4
#
#        Valor Unitário  Valor Final            Loja
#  3980             200          600  Norte Shopping
#  3981              71           71  Norte Shopping
#  3982             116          116  Norte Shopping
#  3983             105          105  Norte Shopping
#  3984              60          300  Norte Shopping
#  ...              ...          ...             ...
#  8154             294          294  Norte Shopping
#  8155             700         1400  Norte Shopping
#  8156              78          156  Norte Shopping
#  8157             259          259  Norte Shopping
#  8158             250         1000  Norte Shopping
#
#  [4179 rows x 8 columns],
#  'Shopping Iguatemi Fortaleza':        Código Venda       Data  ID Loja           Produto  Quantidade
#  88988            71 2019-01-02        4           Relógio           4  \
#  88989            71 2019-01-02        4  Relógio Listrado           4
#  88990           111 2019-01-02        4        Cueca Liso           2
#  88991           187 2019-01-02        4        Short Liso           2
#  88992           248 2019-01-03        4     Pulseira Liso           2
#  ...             ...        ...      ...               ...         ...
#  93004         69910 2019-12-25        4      Chinelo Liso           2
#  93005         69910 2019-12-25        4  Relógio Listrado           2
#  93006         69968 2019-12-25        4        Polo Linho           1
#  93007         69968 2019-12-25        4    Camisa Estampa           3
#  93008         69968 2019-12-25        4        Cueca Liso           5
#
#         Valor Unitário  Valor Final                         Loja
#  88988             200          800  Shopping Iguatemi Fortaleza
#  88989             218          872  Shopping Iguatemi Fortaleza
#  88990              69          138  Shopping Iguatemi Fortaleza
#  88991             108          216  Shopping Iguatemi Fortaleza
#  88992              87          174  Shopping Iguatemi Fortaleza
#  ...               ...          ...                          ...
#  93004              71          142  Shopping Iguatemi Fortaleza
#  93005             218          436  Shopping Iguatemi Fortaleza
#  93006             176          176  Shopping Iguatemi Fortaleza
#  93007             113          339  Shopping Iguatemi Fortaleza
#  93008              69          345  Shopping Iguatemi Fortaleza
#
#  [4021 rows x 8 columns],
#  'Shopping União de Osasco':        Código Venda       Data  ID Loja          Produto  Quantidade
#  56271            26 2019-01-02        5          Chinelo           2  \
#  56272            42 2019-01-02        5          Chinelo           2
#  56273            54 2019-01-02        5     Cueca Xadrez           1
#  56274            54 2019-01-02        5      Cueca Linho           2
#  56275            54 2019-01-02        5        Meia Liso           5
#  ...             ...        ...      ...              ...         ...
#  60261         69940 2019-12-25        5      Polo Xadrez           2
#  60262         69940 2019-12-25        5   Camisa Estampa           2
#  60263         69979 2019-12-26        5    Camisa Gola V           2
#  60264         69979 2019-12-26        5  Mochila Estampa           3
#  60265         69979 2019-12-26        5       Polo Linho           1
#
#         Valor Unitário  Valor Final                      Loja
#  56271              60          120  Shopping União de Osasco
#  56272              60          120  Shopping União de Osasco
#  56273              60           60  Shopping União de Osasco
#  56274              93          186  Shopping União de Osasco
#  56275              38          190  Shopping União de Osasco
#  ...               ...          ...                       ...
#  60261             142          284  Shopping União de Osasco
#  60262             113          226  Shopping União de Osasco
#  60263             100          200  Shopping União de Osasco
#  60264             277          831  Shopping União de Osasco
#  60265             176          176  Shopping União de Osasco
#
#  [3995 rows x 8 columns],
#  'Shopping Center Interlagos':        Código Venda       Data  ID Loja              Produto  Quantidade
#  44335            20 2019-01-02        6         Mochila Liso           1  \
#  44336           112 2019-01-02        6       Calça Listrado           2
#  44337           112 2019-01-02        6  Camisa Gola V Linho           2
#  44338           135 2019-01-02        6       Mochila Xadrez           3
#  44339           135 2019-01-02        6       Camisa Estampa           1
#  ...             ...        ...      ...                  ...         ...
#  48351         69907 2019-12-25        6             Pulseira           1
#  48352         69926 2019-12-25        6           Short Liso           1
#  48353         69926 2019-12-25        6          Calça Linho           1
#  48354         69978 2019-12-26        6         Gorro Xadrez           2
#  48355         69978 2019-12-26        6        Terno Estampa           2
#
#         Valor Unitário  Valor Final                        Loja
#  44335             276          276  Shopping Center Interlagos
#  44336             181          362  Shopping Center Interlagos
#  44337             145          290  Shopping Center Interlagos
#  44338             283          849  Shopping Center Interlagos
#  44339             113          113  Shopping Center Interlagos
#  ...               ...          ...                         ...
#  48351              70           70  Shopping Center Interlagos
#  48352             108          108  Shopping Center Interlagos
#  48353             211          211  Shopping Center Interlagos
#  48354              85          170  Shopping Center Interlagos
#  48355             706         1412  Shopping Center Interlagos
#
#  [4021 rows x 8 columns],
#  'Rio Mar Recife':        Código Venda       Data  ID Loja                 Produto  Quantidade
#  72551            46 2019-01-02        7                  Camisa           1  \
#  72552            46 2019-01-02        7              Calça Liso           2
#  72553            46 2019-01-02        7                   Cinto           1
#  72554            87 2019-01-02        7          Camisa Estampa           1
#  72555           109 2019-01-02        7  Camisa Gola V Listrado           3
#  ...             ...        ...      ...                     ...         ...
#  76645         69905 2019-12-25        7        Mochila Listrado           2
#  76646         69905 2019-12-25        7           Camisa Xadrez           3
#  76647         69905 2019-12-25        7              Tênis Liso           3
#  76648         69954 2019-12-25        7                 Chinelo           3
#  76649         69954 2019-12-25        7         Casaco Listrado           3
#
#         Valor Unitário  Valor Final            Loja
#  72551             100          100  Rio Mar Recife
#  72552             190          380  Rio Mar Recife
#  72553             200          200  Rio Mar Recife
#  72554             113          113  Rio Mar Recife
#  72555             116          348  Rio Mar Recife
#  ...               ...          ...             ...
#  76645             275          550  Rio Mar Recife
#  76646             105          315  Rio Mar Recife
#  76647             266          798  Rio Mar Recife
#  76648              60          180  Rio Mar Recife
#  76649             269          807  Rio Mar Recife
#
#  [4099 rows x 8 columns],
#  'Salvador Shopping':         Código Venda       Data  ID Loja              Produto  Quantidade
#  96969             81 2019-01-02        8         Cueca Xadrez           1  \
#  96970            126 2019-01-02        8       Camisa Estampa           1
#  96971            138 2019-01-02        8       Pulseira Linho           5
#  96972            177 2019-01-02        8          Camisa Liso           2
#  96973            194 2019-01-02        8  Camisa Gola V Linho           4
#  ...              ...        ...      ...                  ...         ...
#  100994         69846 2019-12-25        8        Short Estampa           2
#  100995         69846 2019-12-25        8        Tênis Estampa           5
#  100996         69850 2019-12-25        8        Calça Estampa           4
#  100997         69972 2019-12-26        8           Terno Liso           3
#  100998         69972 2019-12-26        8       Sapato Estampa           5
#
#          Valor Unitário  Valor Final               Loja
#  96969               60           60  Salvador Shopping
#  96970              113          113  Salvador Shopping
#  96971              114          570  Salvador Shopping
#  96972              105          210  Salvador Shopping
#  96973              145          580  Salvador Shopping
#  ...                ...          ...                ...
#  100994              96          192  Salvador Shopping
#  100995             256         1280  Salvador Shopping
#  100996             177          708  Salvador Shopping
#  100997             720         2160  Salvador Shopping
#  100998             358         1790  Salvador Shopping
#
#  [4030 rows x 8 columns],
#  'Rio Mar Shopping Fortaleza':        Código Venda       Data  ID Loja           Produto  Quantidade
#  8159              3 2019-01-02        9       Cinto Linho           1  \
#  8160             18 2019-01-02        9    Camisa Estampa           1
#  8161             27 2019-01-02        9       Sunga Linho           1
#  8162             27 2019-01-02        9    Terno Listrado           2
#  8163             36 2019-01-02        9     Meia Listrado           1
#  ...             ...        ...      ...               ...         ...
#  12272         69773 2019-12-25        9  Pulseira Estampa           1
#  12273         69930 2019-12-25        9     Polo Listrado           1
#  12274         69930 2019-12-25        9     Sunga Estampa           2
#  12275         69961 2019-12-25        9       Polo Xadrez           4
#  12276         69993 2019-12-26        9     Sapato Xadrez           1
#
#         Valor Unitário  Valor Final                        Loja
#  8159              248          248  Rio Mar Shopping Fortaleza
#  8160              113          113  Rio Mar Shopping Fortaleza
#  8161              149          149  Rio Mar Shopping Fortaleza
#  8162              709         1418  Rio Mar Shopping Fortaleza
#  8163               37           37  Rio Mar Shopping Fortaleza
#  ...               ...          ...                         ...
#  12272              87           87  Rio Mar Shopping Fortaleza
#  12273             149          149  Rio Mar Shopping Fortaleza
#  12274             120          240  Rio Mar Shopping Fortaleza
#  12275             142          568  Rio Mar Shopping Fortaleza
#  12276             368          368  Rio Mar Shopping Fortaleza
#
#  [4118 rows x 8 columns],
#  'Shopping Center Leste Aricanduva':        Código Venda       Data  ID Loja         Produto  Quantidade
#  24398             9 2019-01-02       10     Tênis Linho           1  \
#  24399             9 2019-01-02       10   Casaco Xadrez           2
#  24400            29 2019-01-02       10      Gorro Liso           4
#  24401            70 2019-01-02       10     Gorro Linho           2
#  24402            70 2019-01-02       10    Cueca Xadrez           1
#  ...             ...        ...      ...             ...         ...
#  28486         69922 2019-12-25       10            Meia           1
#  28487         69922 2019-12-25       10     Cinto Linho           1
#  28488         69922 2019-12-25       10    Short Xadrez           2
#  28489         69975 2019-12-26       10   Cueca Estampa           5
#  28490         69975 2019-12-26       10  Bermuda Xadrez           1
#
#         Valor Unitário  Valor Final                              Loja
#  24398             294          294  Shopping Center Leste Aricanduva
#  24399             259          518  Shopping Center Leste Aricanduva
#  24400              92          368  Shopping Center Leste Aricanduva
#  24401             124          248  Shopping Center Leste Aricanduva
#  24402              60           60  Shopping Center Leste Aricanduva
#  ...               ...          ...                               ...
#  28486              30           30  Shopping Center Leste Aricanduva
#  28487             248          248  Shopping Center Leste Aricanduva
#  28488             100          200  Shopping Center Leste Aricanduva
#  28489              66          330  Shopping Center Leste Aricanduva
#  28490             155          155  Shopping Center Leste Aricanduva
#
#  [4093 rows x 8 columns],
#  'Ribeirão Shopping':        Código Venda       Data  ID Loja                Produto  Quantidade
#  84940            62 2019-01-02       11  Camisa Gola V Estampa           1  \
#  84941            62 2019-01-02       11        Chinelo Estampa           2
#  84942            84 2019-01-02       11        Pulseira Xadrez           5
#  84943            84 2019-01-02       11            Sapato Liso           3
#  84944            84 2019-01-02       11                  Calça           1
#  ...             ...        ...      ...                    ...         ...
#  88983         69967 2019-12-25       11                  Short           1
#  88984         69967 2019-12-25       11          Bermuda Linho           1
#  88985         69984 2019-12-26       11             Cueca Liso           4
#  88986         69997 2019-12-26       11        Camisa Listrado           1
#  88987         69997 2019-12-26       11            Short Linho           2
#
#         Valor Unitário  Valor Final               Loja
#  84940             118          118  Ribeirão Shopping
#  84941              74          148  Ribeirão Shopping
#  84942              87          435  Ribeirão Shopping
#  84943             368         1104  Ribeirão Shopping
#  84944             170          170  Ribeirão Shopping
#  ...               ...          ...                ...
#  88983              90           90  Ribeirão Shopping
#  88984             195          195  Ribeirão Shopping
#  88985              69          276  Ribeirão Shopping
#  88986             108          108  Ribeirão Shopping
#  88987             133          266  Ribeirão Shopping
#
#  [4048 rows x 8 columns],
#  'Shopping Morumbi':        Código Venda       Data  ID Loja         Produto  Quantidade
#  93009            72 2019-01-02       12   Gorro Estampa           2  \
#  93010            72 2019-01-02       12   Sapato Xadrez           4
#  93011            75 2019-01-02       12   Sapato Xadrez           2
#  93012            75 2019-01-02       12           Cueca           2
#  93013            88 2019-01-02       12  Gorro Listrado           1
#  ...             ...        ...      ...             ...         ...
#  96964         69877 2019-12-25       12     Polo Xadrez           2
#  96965         69877 2019-12-25       12            Polo           1
#  96966         69904 2019-12-25       12      Polo Linho           1
#  96967         69904 2019-12-25       12  Gorro Listrado           3
#  96968         69931 2019-12-25       12      Gorro Liso           3
#
#         Valor Unitário  Valor Final              Loja
#  93009              93          186  Shopping Morumbi
#  93010             368         1472  Shopping Morumbi
#  93011             368          736  Shopping Morumbi
#  93012              50          100  Shopping Morumbi
#  93013              97           97  Shopping Morumbi
#  ...               ...          ...               ...
#  96964             142          284  Shopping Morumbi
#  96965             130          130  Shopping Morumbi
#  96966             176          176  Shopping Morumbi
#  96967              97          291  Shopping Morumbi
#  96968              92          276  Shopping Morumbi
#
#  [3960 rows x 8 columns],
#  'Parque Dom Pedro Shopping':        Código Venda       Data  ID Loja           Produto  Quantidade
#  48356            22 2019-01-02       13              Meia           1  \
#  48357            22 2019-01-02       13        Meia Linho           2
#  48358            22 2019-01-02       13        Calça Liso           2
#  48359            35 2019-01-02       13           Relógio           2
#  48360            35 2019-01-02       13            Sapato           2
#  ...             ...        ...      ...               ...         ...
#  52253         69796 2019-12-25       13        Tênis Liso           4
#  52254         69804 2019-12-25       13  Camiseta Estampa           1
#  52255         69804 2019-12-25       13      Camisa Linho           3
#  52256         69871 2019-12-25       13   Chinelo Estampa           1
#  52257         69943 2019-12-25       13    Relógio Xadrez           1
#
#         Valor Unitário  Valor Final                       Loja
#  48356              30           30  Parque Dom Pedro Shopping
#  48357              78          156  Parque Dom Pedro Shopping
#  48358             190          380  Parque Dom Pedro Shopping
#  48359             200          400  Parque Dom Pedro Shopping
#  48360             350          700  Parque Dom Pedro Shopping
#  ...               ...          ...                        ...
#  52253             266         1064  Parque Dom Pedro Shopping
#  52254             196          196  Parque Dom Pedro Shopping
#  52255             141          423  Parque Dom Pedro Shopping
#  52256              74           74  Parque Dom Pedro Shopping
#  52257             214          214  Parque Dom Pedro Shopping
#
#  [3902 rows x 8 columns],
#  'Bourbon Shopping SP':        Código Venda       Data  ID Loja          Produto  Quantidade
#  40219            14 2019-01-02       14      Casaco Liso           2  \
#  40220            99 2019-01-02       14    Sapato Xadrez           2
#  40221            99 2019-01-02       14       Short Liso           5
#  40222            99 2019-01-02       14   Cinto Listrado           4
#  40223           110 2019-01-02       14     Polo Estampa           2
#  ...             ...        ...      ...              ...         ...
#  44330         69889 2019-12-25       14          Mochila           1
#  44331         69932 2019-12-25       14  Camiseta Xadrez           3
#  44332         69953 2019-12-25       14             Polo           5
#  44333         69953 2019-12-25       14            Tênis           1
#  44334         69987 2019-12-26       14  Bermuda Estampa           4
#
#         Valor Unitário  Valor Final                 Loja
#  40219             255          510  Bourbon Shopping SP
#  40220             368          736  Bourbon Shopping SP
#  40221             108          540  Bourbon Shopping SP
#  40222             214          856  Bourbon Shopping SP
#  40223             138          276  Bourbon Shopping SP
#  ...               ...          ...                  ...
#  44330             270          270  Bourbon Shopping SP
#  44331             200          600  Bourbon Shopping SP
#  44332             130          650  Bourbon Shopping SP
#  44333             250          250  Bourbon Shopping SP
#  44334             169          676  Bourbon Shopping SP
#
#  [4116 rows x 8 columns],
#  'Palladium Shopping Curitiba':        Código Venda       Data  ID Loja             Produto  Quantidade
#  76650            47 2019-01-02       15               Short           1  \
#  76651            59 2019-01-02       15               Calça           2
#  76652            66 2019-01-02       15              Casaco           4
#  76653            66 2019-01-02       15      Camiseta Linho           1
#  76654            94 2019-01-02       15     Relógio Estampa           4
#  ...             ...        ...      ...                 ...         ...
#  80855         69872 2019-12-25       15   Camiseta Listrado           1
#  80856         69947 2019-12-25       15  Camisa Gola V Liso           2
#  80857         69956 2019-12-25       15       Mochila Linho           1
#  80858         69980 2019-12-26       15        Casaco Linho           1
#  80859         69983 2019-12-26       15         Meia Xadrez           2
#
#         Valor Unitário  Valor Final                         Loja
#  76650              90           90  Palladium Shopping Curitiba
#  76651             170          340  Palladium Shopping Curitiba
#  76652             250         1000  Palladium Shopping Curitiba
#  76653             223          223  Palladium Shopping Curitiba
#  76654             219          876  Palladium Shopping Curitiba
#  ...               ...          ...                          ...
#  80855             197          197  Palladium Shopping Curitiba
#  80856             118          236  Palladium Shopping Curitiba
#  80857             311          311  Palladium Shopping Curitiba
#  80858             299          299  Palladium Shopping Curitiba
#  80859              41           82  Palladium Shopping Curitiba
#
#  [4210 rows x 8 columns],
#  'Passei das Águas Shopping':        Código Venda       Data  ID Loja           Produto  Quantidade
#  28491            10 2019-01-02       16   Camiseta Xadrez           2  \
#  28492            10 2019-01-02       16        Cueca Liso           1
#  28493            19 2019-01-02       16  Relógio Listrado           1
#  28494            19 2019-01-02       16       Calça Linho           2
#  28495           199 2019-01-02       16          Camiseta           2
#  ...             ...        ...      ...               ...         ...
#  32486         69745 2019-12-24       16          Camiseta           3
#  32487         69861 2019-12-25       16       Terno Linho           5
#  32488         69861 2019-12-25       16   Camiseta Xadrez           2
#  32489         69937 2019-12-25       16      Sunga Xadrez           5
#  32490         69957 2019-12-25       16   Bermuda Estampa           1
#
#         Valor Unitário  Valor Final                       Loja
#  28491             200          400  Passei das Águas Shopping
#  28492              69           69  Passei das Águas Shopping
#  28493             218          218  Passei das Águas Shopping
#  28494             211          422  Passei das Águas Shopping
#  28495             180          360  Passei das Águas Shopping
#  ...               ...          ...                        ...
#  32486             180          540  Passei das Águas Shopping
#  32487             750         3750  Passei das Águas Shopping
#  32488             200          400  Passei das Águas Shopping
#  32489             116          580  Passei das Águas Shopping
#  32490             169          169  Passei das Águas Shopping
#
#  [4000 rows x 8 columns],
#  'Center Shopping Uberlândia':        Código Venda       Data  ID Loja           Produto  Quantidade
#  52258            23 2019-01-02       17   Bermuda Estampa           3  \
#  52259            23 2019-01-02       17      Chinelo Liso           3
#  52260            65 2019-01-02       17    Gorro Listrado           1
#  52261            65 2019-01-02       17      Gorro Xadrez           1
#  52262            80 2019-01-02       17        Meia Linho           3
#  ...             ...        ...      ...               ...         ...
#  56266         69991 2019-12-26       17           Mochila           4
#  56267         69991 2019-12-26       17   Camiseta Xadrez           1
#  56268         69996 2019-12-26       17    Short Listrado           2
#  56269         69996 2019-12-26       17           Mochila           4
#  56270         69996 2019-12-26       17  Pulseira Estampa           1
#
#         Valor Unitário  Valor Final                        Loja
#  52258             169          507  Center Shopping Uberlândia
#  52259              71          213  Center Shopping Uberlândia
#  52260              97           97  Center Shopping Uberlândia
#  52261              85           85  Center Shopping Uberlândia
#  52262              78          234  Center Shopping Uberlândia
#  ...               ...          ...                         ...
#  56266             270         1080  Center Shopping Uberlândia
#  56267             200          200  Center Shopping Uberlândia
#  56268             102          204  Center Shopping Uberlândia
#  56269             270         1080  Center Shopping Uberlândia
#  56270              87           87  Center Shopping Uberlândia
#
#  [4013 rows x 8 columns],
#  'Shopping Recife':        Código Venda       Data  ID Loja           Produto  Quantidade
#  32491            11 2019-01-02       18          Camiseta           1  \
#  32492            11 2019-01-02       18    Calça Listrado           2
#  32493            11 2019-01-02       18    Camisa Estampa           1
#  32494            45 2019-01-02       18      Camisa Linho           1
#  32495            96 2019-01-02       18       Meia Xadrez           1
#  ...             ...        ...      ...               ...         ...
#  36377         69925 2019-12-25       18        Gorro Liso           2
#  36378         69936 2019-12-25       18       Terno Linho           1
#  36379         69971 2019-12-26       18        Cinto Liso           2
#  36380         69971 2019-12-26       18  Bermuda Listrado           2
#  36381         69982 2019-12-26       18     Mochila Linho           2
#
#         Valor Unitário  Valor Final             Loja
#  32491             180          180  Shopping Recife
#  32492             181          362  Shopping Recife
#  32493             113          113  Shopping Recife
#  32494             141          141  Shopping Recife
#  32495              41           41  Shopping Recife
#  ...               ...          ...              ...
#  36377              92          184  Shopping Recife
#  36378             750          750  Shopping Recife
#  36379             209          418  Shopping Recife
#  36380             163          326  Shopping Recife
#  36381             311          622  Shopping Recife
#
#  [3891 rows x 8 columns],
#  'Shopping Vila Velha':        Código Venda       Data  ID Loja         Produto  Quantidade
#  64268            32 2019-01-02       19       Polo Liso           1  \
#  64269            32 2019-01-02       19   Polo Listrado           2
#  64270            38 2019-01-02       19     Meia Xadrez           3
#  64271            38 2019-01-02       19         Relógio           1
#  64272            82 2019-01-02       19   Meia Listrado           1
#  ...             ...        ...      ...             ...         ...
#  68497         69801 2019-12-25       19         Bermuda           3
#  68498         69859 2019-12-25       19       Meia Liso           2
#  68499         69970 2019-12-26       19    Casaco Linho           2
#  68500         69974 2019-12-26       19   Meia Listrado           3
#  68501         69985 2019-12-26       19  Pulseira Linho           2
#
#         Valor Unitário  Valor Final                 Loja
#  64268             137          137  Shopping Vila Velha
#  64269             149          298  Shopping Vila Velha
#  64270              41          123  Shopping Vila Velha
#  64271             200          200  Shopping Vila Velha
#  64272              37           37  Shopping Vila Velha
#  ...               ...          ...                  ...
#  68497             150          450  Shopping Vila Velha
#  68498              38           76  Shopping Vila Velha
#  68499             299          598  Shopping Vila Velha
#  68500              37          111  Shopping Vila Velha
#  68501             114          228  Shopping Vila Velha
#
#  [4234 rows x 8 columns],
#  'Shopping SP Market':        Código Venda       Data  ID Loja         Produto  Quantidade
#  80860            56 2019-01-02       20     Gorro Linho           3  \
#  80861            60 2019-01-02       20    Casaco Linho           3
#  80862            60 2019-01-02       20       Polo Liso           5
#  80863            67 2019-01-02       20      Polo Linho           3
#  80864           101 2019-01-02       20  Cinto Listrado           2
#  ...             ...        ...      ...             ...         ...
#  84935         69960 2019-12-25       20            Polo           2
#  84936         69960 2019-12-25       20     Sapato Liso           1
#  84937         69960 2019-12-25       20  Sapato Estampa           3
#  84938         69969 2019-12-25       20   Pulseira Liso           1
#  84939         69969 2019-12-25       20   Camiseta Liso           2
#
#         Valor Unitário  Valor Final                Loja
#  80860             124          372  Shopping SP Market
#  80861             299          897  Shopping SP Market
#  80862             137          685  Shopping SP Market
#  80863             176          528  Shopping SP Market
#  80864             214          428  Shopping SP Market
#  ...               ...          ...                 ...
#  84935             130          260  Shopping SP Market
#  84936             368          368  Shopping SP Market
#  84937             358         1074  Shopping SP Market
#  84938              87           87  Shopping SP Market
#  84939             187          374  Shopping SP Market
#
#  [4080 rows x 8 columns],
#  'Shopping Eldorado':        Código Venda       Data  ID Loja         Produto  Quantidade
#  60266            31 2019-01-02       21  Casaco Estampa           3  \
#  60267            31 2019-01-02       21        Pulseira           3
#  60268            31 2019-01-02       21     Gorro Linho           1
#  60269            31 2019-01-02       21     Cinto Linho           3
#  60270            40 2019-01-02       21   Bermuda Linho           1
#  ...             ...        ...      ...             ...         ...
#  64263         69959 2019-12-25       21       Polo Liso           4
#  64264         69959 2019-12-25       21    Camisa Linho           3
#  64265         69959 2019-12-25       21    Cueca Xadrez           1
#  64266         69986 2019-12-26       21   Cueca Estampa           4
#  64267         69986 2019-12-26       21  Terno Listrado           3
#
#         Valor Unitário  Valor Final               Loja
#  60266             256          768  Shopping Eldorado
#  60267              70          210  Shopping Eldorado
#  60268             124          124  Shopping Eldorado
#  60269             248          744  Shopping Eldorado
#  60270             195          195  Shopping Eldorado
#  ...               ...          ...                ...
#  64263             137          548  Shopping Eldorado
#  64264             141          423  Shopping Eldorado
#  64265              60           60  Shopping Eldorado
#  64266              66          264  Shopping Eldorado
#  64267             709         2127  Shopping Eldorado
#
#  [4002 rows x 8 columns],
#  'Shopping Ibirapuera':        Código Venda       Data  ID Loja                Produto  Quantidade
#  16239             6 2019-01-02       22          Polo Listrado           4  \
#  16240            44 2019-01-02       22                  Calça           2
#  16241            44 2019-01-02       22        Camisa Listrado           1
#  16242            44 2019-01-02       22            Camisa Liso           2
#  16243            69 2019-01-02       22            Meia Xadrez           1
#  ...             ...        ...      ...                    ...         ...
#  20285         69880 2019-12-25       22         Mochila Xadrez           2
#  20286         69941 2019-12-25       22             Cueca Liso           5
#  20287         69946 2019-12-25       22           Calça Xadrez           1
#  20288         69946 2019-12-25       22           Gorro Xadrez           1
#  20289         69977 2019-12-26       22  Camisa Gola V Estampa           1
#
#         Valor Unitário  Valor Final                 Loja
#  16239             149          596  Shopping Ibirapuera
#  16240             170          340  Shopping Ibirapuera
#  16241             108          108  Shopping Ibirapuera
#  16242             105          210  Shopping Ibirapuera
#  16243              41           41  Shopping Ibirapuera
#  ...               ...          ...                  ...
#  20285             283          566  Shopping Ibirapuera
#  20286              69          345  Shopping Ibirapuera
#  20287             185          185  Shopping Ibirapuera
#  20288              85           85  Shopping Ibirapuera
#  20289             118          118  Shopping Ibirapuera
#
#  [4051 rows x 8 columns],
#  'Novo Shopping Ribeirão Preto':        Código Venda       Data  ID Loja                 Produto  Quantidade
#  68502            41 2019-01-02       23                   Gorro           1  \
#  68503            41 2019-01-02       23            Short Xadrez           4
#  68504            61 2019-01-02       23  Camisa Gola V Listrado           1
#  68505            61 2019-01-02       23          Camisa Estampa           2
#  68506            93 2019-01-02       23           Camiseta Liso           1
#  ...             ...        ...      ...                     ...         ...
#  72546         69981 2019-12-26       23        Camiseta Estampa           1
#  72547         69981 2019-12-26       23              Meia Linho           1
#  72548         69981 2019-12-26       23          Sunga Listrado           2
#  72549         69995 2019-12-26       23          Cinto Listrado           3
#  72550         69995 2019-12-26       23                 Mochila           4
#
#         Valor Unitário  Valor Final                          Loja
#  68502              80           80  Novo Shopping Ribeirão Preto
#  68503             100          400  Novo Shopping Ribeirão Preto
#  68504             116          116  Novo Shopping Ribeirão Preto
#  68505             113          226  Novo Shopping Ribeirão Preto
#  68506             187          187  Novo Shopping Ribeirão Preto
#  ...               ...          ...                           ...
#  72546             196          196  Novo Shopping Ribeirão Preto
#  72547              78           78  Novo Shopping Ribeirão Preto
#  72548             114          228  Novo Shopping Ribeirão Preto
#  72549             214          642  Novo Shopping Ribeirão Preto
#  72550             270         1080  Novo Shopping Ribeirão Preto
#
#  [4049 rows x 8 columns],
#  'Iguatemi Campinas':        Código Venda       Data  ID Loja          Produto  Quantidade
#  20290             8 2019-01-02       24    Terno Estampa           5  \
#  20291            17 2019-01-02       24     Chinelo Liso           1
#  20292           143 2019-01-02       24         Pulseira           3
#  20293           166 2019-01-02       24     Cinto Xadrez           1
#  20294           176 2019-01-02       24   Cinto Listrado           1
#  ...             ...        ...      ...              ...         ...
#  24393         69934 2019-12-25       24  Chinelo Estampa           3
#  24394         69934 2019-12-25       24    Camisa Xadrez           2
#  24395         69934 2019-12-25       24       Tênis Liso           2
#  24396         69934 2019-12-25       24  Casaco Listrado           1
#  24397         69939 2019-12-25       24     Bermuda Liso           5
#
#         Valor Unitário  Valor Final               Loja
#  20290             706         3530  Iguatemi Campinas
#  20291              71           71  Iguatemi Campinas
#  20292              70          210  Iguatemi Campinas
#  20293             215          215  Iguatemi Campinas
#  20294             214          214  Iguatemi Campinas
#  ...               ...          ...                ...
#  24393              74          222  Iguatemi Campinas
#  24394             105          210  Iguatemi Campinas
#  24395             266          532  Iguatemi Campinas
#  24396             269          269  Iguatemi Campinas
#  24397             157          785  Iguatemi Campinas
#
#  [4108 rows x 8 columns],
#  'Shopping Barra':        Código Venda       Data  ID Loja             Produto  Quantidade
#  12277             5 2019-01-02       25               Calça           1  \
#  12278            52 2019-01-02       25      Gorro Listrado           4
#  12279           100 2019-01-02       25  Camisa Gola V Liso           3
#  12280           100 2019-01-02       25        Cinto Xadrez           4
#  12281           132 2019-01-02       25         Terno Linho           2
#  ...             ...        ...      ...                 ...         ...
#  16234         69908 2019-12-25       25           Meia Liso           2
#  16235         69908 2019-12-25       25              Camisa           1
#  16236         69913 2019-12-25       25               Gorro           1
#  16237         69913 2019-12-25       25         Cinto Linho           1
#  16238         69950 2019-12-25       25         Cinto Linho           1
#
#         Valor Unitário  Valor Final            Loja
#  12277             170          170  Shopping Barra
#  12278              97          388  Shopping Barra
#  12279             118          354  Shopping Barra
#  12280             215          860  Shopping Barra
#  12281             750         1500  Shopping Barra
#  ...               ...          ...             ...
#  16234              38           76  Shopping Barra
#  16235             100          100  Shopping Barra
#  16236              80           80  Shopping Barra
#  16237             248          248  Shopping Barra
#  16238             248          248  Shopping Barra
#
#  [3962 rows x 8 columns]}

# %%
display(dicionario_loja["Shopping Vila Velha"])
# Out:
#        Código Venda       Data  ID Loja         Produto  Quantidade
# 64268            32 2019-01-02       19       Polo Liso           1  \
# 64269            32 2019-01-02       19   Polo Listrado           2
# 64270            38 2019-01-02       19     Meia Xadrez           3
# 64271            38 2019-01-02       19         Relógio           1
# 64272            82 2019-01-02       19   Meia Listrado           1
# ...             ...        ...      ...             ...         ...
# 68497         69801 2019-12-25       19         Bermuda           3
# 68498         69859 2019-12-25       19       Meia Liso           2
# 68499         69970 2019-12-26       19    Casaco Linho           2
# 68500         69974 2019-12-26       19   Meia Listrado           3
# 68501         69985 2019-12-26       19  Pulseira Linho           2
#
#        Valor Unitário  Valor Final                 Loja
# 64268             137          137  Shopping Vila Velha
# 64269             149          298  Shopping Vila Velha
# 64270              41          123  Shopping Vila Velha
# 64271             200          200  Shopping Vila Velha
# 64272              37           37  Shopping Vila Velha
# ...               ...          ...                  ...
# 68497             150          450  Shopping Vila Velha
# 68498              38           76  Shopping Vila Velha
# 68499             299          598  Shopping Vila Velha
# 68500              37          111  Shopping Vila Velha
# 68501             114          228  Shopping Vila Velha
#
# [4234 rows x 8 columns]

# %% [markdown]
# #### Data máxima

# %%
# Data
data_maxima = vendas_df["Data"].max()
print(data_maxima)

# Dia
dia_data_maxima = data_maxima.day
print(dia_data_maxima)

# Mês
mes_data_maxima = data_maxima.month
print(mes_data_maxima)

# Ano
ano_data_maxima = data_maxima.year
print(ano_data_maxima)
# Out:
# 2019-12-26 00:00:00
# 26
# 12
# 2019

# %% [markdown]
# ### Passo 3 - Salvar a planilha na pasta de backup

# %%
caminho_backup = Path('Backup Arquivos Lojas')

pastas = caminho_backup.iterdir()

# Percorre cada loja no dicionario (sem valores repetidos da loja)
for loja in dicionario_loja:

    # Confere se a loja não tem uma pasta criada
    if not (caminho_backup / loja).exists():

        print(loja)
        
        # Cria pasta com nomes das lojas
        Path(caminho_backup / loja).mkdir()
        
        # Nome no arquivo em excel
        nome_arquivo = f"{loja} - {dia_data_maxima}.{mes_data_maxima}.xlsx"
        caminho_arquivo_loja = caminho_backup / loja / nome_arquivo
        
        # Cria arquivos para cada loja
        dicionario_loja[loja].to_excel(caminho_arquivo_loja)

# %% [markdown]
# ### Passo 4 - Calcular o indicador para 1 loja

# %%
meta_faturamento_ano = 1650000
meta_faturamento_dia = 1000
meta_qtde_produtos_ano = 120
meta_qtde_produtos_dia = 4
meta_ticket_ano = 500
meta_ticket_dia = 500

# %%
# E-mail
outlook = win32.Dispatch('outlook.application')

# Para cada loja na tabela
for loja in lojas_df["Loja"]:
    
    # Filtro
    tabela_loja_ano = vendas_df["Loja"] == loja
    tabela_loja_dia = (vendas_df["Loja"] == loja) & (vendas_df["Data"] == data_maxima)
    
    # Indicador de Faturamento
    faturamento_loja_ano = vendas_df.loc[tabela_loja_ano]["Valor Final"].sum()
    faturamento_loja_dia = vendas_df[tabela_loja_dia]["Valor Final"].sum()
    
    # Indicador de Diversidade de Produtos
    qtde_produtos_ano = len(vendas_df.loc[tabela_loja_ano]["Produto"].unique())
    qtde_produtos_dia = len(vendas_df.loc[tabela_loja_dia]["Produto"].unique())
    
    # Indicador de Ticket Médio
    tabela_sem_data = vendas_df.drop(columns=['Data'])
    vendas_codigo_ano = tabela_sem_data.loc[tabela_loja_ano].groupby("Código Venda").sum()
    ticket_medio_ano = vendas_codigo_ano["Valor Final"].mean()
    vendas_codigo_dia = tabela_sem_data.loc[tabela_loja_dia].groupby("Código Venda").sum()
    ticket_medio_dia = vendas_codigo_dia["Valor Final"].mean()
    
    # Criar e-mail
    email = outlook.CreateItem(0)
    
    # Filtro do e-mail
    filtro_email_loja = emails_df["Loja"] == loja
    data_maxima_formatada = f"{dia_data_maxima}/{mes_data_maxima}/{ano_data_maxima}"
    
    # Para
    email_loja = emails_df.loc[filtro_email_loja, "E-mail"].values[0]
    nome_gerente = emails_df.loc[filtro_email_loja, "Gerente"].values[0]
    email.to = email_loja
    
    # Assunto
    email.Subject = f"OnePage Dia {data_maxima_formatada} - Loja {loja}"
    
    # Anexo
    caminho_padrao = Path.cwd()
    nome_arquivo = f"{loja} - {dia_data_maxima}.{mes_data_maxima}.xlsx"
    caminho_arquivo = caminho_padrao / "Backup Arquivos Lojas" / loja / nome_arquivo
    email.Attachments.Add(str(caminho_arquivo))
    
    # Status dos indicadores
    if faturamento_loja_ano >= meta_faturamento_ano:
        cor_faturamento_loja_ano = "green"
    else:
        cor_faturamento_loja_ano = "red"
    
    if faturamento_loja_dia >= meta_faturamento_dia:
        cor_faturamento_loja_dia = "green"
    else:
        cor_faturamento_loja_dia = "red"
        
    if qtde_produtos_ano >= meta_qtde_produtos_ano:
        cor_qtde_produtos_ano = "green"
    else:
        cor_qtde_produtos_ano = "red"
        
    if qtde_produtos_dia >= meta_qtde_produtos_dia:
        cor_qtde_produtos_dia = "green"
    else:
        cor_qtde_produtos_dia = "red"
        
    if ticket_medio_ano >= meta_ticket_ano:
        cor_ticket_medio_ano = "green"
    else:
        cor_ticket_medio_ano = "red"
        
    if ticket_medio_dia >= meta_ticket_dia:
        cor_ticket_medio_dia = "green"
    else:
        cor_ticket_medio_dia = "red"
        
    # Corpo do e-mail
    email.HtmlBody = f'''
    <p>Bom dia, {nome_gerente}</p>
    
    <p>O Resultado do dia {data_maxima_formatada} da Loja {loja} foi:</p>
    
    <table>
        <tr>
            <th style="text-align: left">Indicador</th>
            <th>Valor dia</th>
            <th>Meta dia</th>
            <th>Cenário dia</th>
        </tr>
        <tr>
            <td>Faturamento</td>
            <td  style="text-align: center">R$ {faturamento_loja_dia:.2f}</td>
            <td  style="text-align: center">R$ {meta_faturamento_dia:.2f}</td>
            <td  style="text-align: center"><font color="{cor_faturamento_loja_dia}">◙</font></td>
        <tr>
            <td>Qtde de Produtos</td>
            <td  style="text-align: center">{qtde_produtos_dia}</td>
            <td  style="text-align: center">{meta_qtde_produtos_dia}</td>
            <td  style="text-align: center"><font color="{cor_qtde_produtos_dia}">◙</font></td>
        </tr>
        <tr>
            <td>Ticket Médio</td>
            <td  style="text-align: center">R$ {ticket_medio_dia:.2f}</td>
            <td  style="text-align: center">R$ {meta_ticket_dia:.2f}</td>
            <td  style="text-align: center"><font color="{cor_ticket_medio_dia}">◙</font></td>
        </tr>
        <br>
        <tr>
            <th style="text-align: left">Indicador</th>
            <th>Valor ano</th>
            <th>Meta ano</th>
            <th>Cenário ano</th>
        </tr>
        <tr>
            <td>Faturamento</td>
            <td  style="text-align: center">R$ {faturamento_loja_ano:.2f}</td>
            <td  style="text-align: center">R$ {meta_faturamento_ano:.2f}</td>
            <td  style="text-align: center"><font color="{cor_faturamento_loja_ano}">◙</font></td>
        <tr>
            <td>Qtde de Produtos</td>
            <td  style="text-align: center">{qtde_produtos_ano}</td>
            <td  style="text-align: center">{meta_qtde_produtos_ano}</td>
            <td  style="text-align: center"><font color="{cor_qtde_produtos_ano}">◙</font></td>
        </tr>
        <tr>
            <td>Ticket Médio</td>
            <td  style="text-align: center">R$ {ticket_medio_ano:.2f}</td>
            <td  style="text-align: center">R$ {meta_ticket_ano:.2f}</td>
            <td  style="text-align: center"><font color="{cor_ticket_medio_ano}">◙</font></td>
        </tr>
        
        <p>Segue em anexo a planilha com todos os dados para mais detalhes.</p>

        <p>Qualquer dúvida estou à disposição.</p>
        <p>Att., Lucas Galvão</p>
    '''
    
    # Enviar
    email.Send()
    print(f"Email da loja {loja} enviado com sucesso")
# Out:
# Email da loja Iguatemi Esplanada enviado com sucesso
# Email da loja Shopping Midway Mall enviado com sucesso
# Email da loja Norte Shopping enviado com sucesso
# Email da loja Shopping Iguatemi Fortaleza enviado com sucesso
# Email da loja Shopping União de Osasco enviado com sucesso
# Email da loja Shopping Center Interlagos enviado com sucesso
# Email da loja Rio Mar Recife enviado com sucesso
# Email da loja Salvador Shopping enviado com sucesso
# Email da loja Rio Mar Shopping Fortaleza enviado com sucesso
# Email da loja Shopping Center Leste Aricanduva enviado com sucesso
# Email da loja Ribeirão Shopping enviado com sucesso
# Email da loja Shopping Morumbi enviado com sucesso
# Email da loja Parque Dom Pedro Shopping enviado com sucesso
# Email da loja Bourbon Shopping SP enviado com sucesso
# Email da loja Palladium Shopping Curitiba enviado com sucesso
# Email da loja Passei das Águas Shopping enviado com sucesso
# Email da loja Center Shopping Uberlândia enviado com sucesso
# Email da loja Shopping Recife enviado com sucesso
# Email da loja Shopping Vila Velha enviado com sucesso
# Email da loja Shopping SP Market enviado com sucesso
# Email da loja Shopping Eldorado enviado com sucesso
# Email da loja Shopping Ibirapuera enviado com sucesso
# Email da loja Novo Shopping Ribeirão Preto enviado com sucesso
# Email da loja Iguatemi Campinas enviado com sucesso
# Email da loja Shopping Barra enviado com sucesso

# %% [markdown]
# ### Passo 5 - Enviar por e-mail para o gerente

# %% [markdown]
# ### Passo 6 - Automatizar todas as lojas

# %% [markdown]
# ### Passo 7 - Criar ranking para diretoria

# %%
# Ranking do faturamento no ano
tabela_sem_data = vendas_df.drop(columns=['Data'])
faturamento_por_loja_ano = tabela_sem_data.groupby("Loja").sum()[["Valor Final"]]
faturamento_ranking_lojas_ano = faturamento_por_loja_ano.sort_values(by="Valor Final", ascending=False)
display(faturamento_ranking_lojas_ano)
# Out:
#                                   Valor Final
# Loja
# Iguatemi Campinas                     1762419
# Shopping Vila Velha                   1731167
# Bourbon Shopping SP                   1726110
# Rio Mar Recife                        1722766
# Shopping SP Market                    1721763
# Palladium Shopping Curitiba           1721120
# Norte Shopping                        1711968
# Ribeirão Shopping                     1707122
# Iguatemi Esplanada                    1699681
# Rio Mar Shopping Fortaleza            1698430
# Shopping Center Leste Aricanduva      1682870
# Novo Shopping Ribeirão Preto          1678225
# Shopping Iguatemi Fortaleza           1674824
# Center Shopping Uberlândia            1668921
# Shopping União de Osasco              1663770
# Shopping Barra                        1653103
# Passei das Águas Shopping             1649014
# Shopping Eldorado                     1648111
# Salvador Shopping                     1646739
# Shopping Center Interlagos            1640486
# Shopping Ibirapuera                   1635060
# Parque Dom Pedro Shopping             1631630
# Shopping Recife                       1624879
# Shopping Midway Mall                  1590441
# Shopping Morumbi                      1586444

# %%
# Melhor Loja
maior_faturamento_loja_ano = faturamento_ranking_lojas_ano["Valor Final"].max()
melhor_loja_ano = faturamento_ranking_lojas_ano.index[0]
print('Melhor Loja:', melhor_loja_ano)
print('Faturamento:', maior_faturamento_loja_ano)

print()

# Pior Loja
menor_faturamento_loja_ano = faturamento_ranking_lojas_ano["Valor Final"].min()
pior_loja_ano = faturamento_ranking_lojas_ano.index[-1]
print('Pior Loja:', pior_loja_ano)
print('Faturamento:', menor_faturamento_loja_ano)

# Exportar tabela de ranking no Excel
faturamento_ranking_lojas_ano.to_excel(r"Backup Arquivos Lojas/Ranking Lojas no Ano.xlsx")
# Out:
# Melhor Loja: Iguatemi Campinas
# Faturamento: 1762419
#
# Pior Loja: Shopping Morumbi
# Faturamento: 1586444
# <ipython-input-54-e45f55c2f6fa>:16: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   faturamento_ranking_lojas_ano.to_excel(r"Backup Arquivos Lojas/Ranking Lojas no Ano.xlsx")

# %%
# Ranking do faturamento no dia
tabela_filtrada = vendas_df["Data"] == data_maxima
tabela_sem_data = vendas_df.drop(columns=['Data'])
faturamento_por_loja_dia = tabela_sem_data.loc[tabela_filtrada].groupby("Loja").sum()[["Valor Final"]]
faturamento_ranking_lojas_dia = faturamento_por_loja_dia.sort_values(by="Valor Final", ascending=False)
display(faturamento_ranking_lojas_dia)
# Out:
#                                   Valor Final
# Loja
# Salvador Shopping                        3950
# Novo Shopping Ribeirão Preto             3400
# Center Shopping Uberlândia               2651
# Shopping Eldorado                        2391
# Shopping Center Interlagos               1582
# Shopping Recife                          1366
# Norte Shopping                           1259
# Shopping União de Osasco                 1207
# Shopping Vila Velha                       937
# Bourbon Shopping SP                       676
# Ribeirão Shopping                         650
# Shopping Center Leste Aricanduva          485
# Palladium Shopping Curitiba               381
# Rio Mar Shopping Fortaleza                368
# Shopping Midway Mall                      170
# Shopping Ibirapuera                       118

# %%
# Melhor Loja
maior_faturamento_loja_dia = faturamento_ranking_lojas_dia["Valor Final"].max()
melhor_loja_dia = faturamento_ranking_lojas_dia.index[0]
print('Melhor Loja:', melhor_loja_dia)
print('Faturamento:', maior_faturamento_loja_dia)

print()

# Pior Loja
menor_faturamento_loja_dia = faturamento_ranking_lojas_dia["Valor Final"].min()
pior_loja_dia= faturamento_ranking_lojas_dia.index[-1]
print('Pior Loja:', pior_loja_dia)
print('Faturamento:', menor_faturamento_loja_dia)

# Exportar tabela de ranking no Excel
faturamento_ranking_lojas_dia.to_excel(r"Backup Arquivos Lojas/Ranking Lojas em {}.{}.{}.xlsx"
                                       .format(dia_data_maxima, mes_data_maxima, ano_data_maxima))
# Out:
# Melhor Loja: Salvador Shopping
# Faturamento: 3950
#
# Pior Loja: Shopping Ibirapuera
# Faturamento: 118
# <ipython-input-53-9c3611af609a>:16: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   faturamento_ranking_lojas_dia.to_excel(r"Backup Arquivos Lojas/Ranking Lojas em {}.{}.{}.xlsx"

# %% [markdown]
# ### Passo 8 - Enviar e-mail para diretoria

# %%
# E-mail no Outlook
outlook = win32.Dispatch('outlook.application')

# Criar e-mail
email = outlook.CreateItem(0)

# Filtro do e-mail
filtro_email_loja = emails_df["Loja"] == "Diretoria"

email_loja = emails_df.loc[filtro_email_loja, "E-mail"].values[0]
email.to = email_loja

# Assunto
email.Subject = f"Ranking Lojas {data_maxima_formatada}"

# Anexos
caminho_padrao = Path.cwd()
nome_arquivo = f"Ranking Lojas em {dia_data_maxima}.{mes_data_maxima}.{ano_data_maxima}.xlsx"
caminho_arquivo = caminho_padrao / "Backup Arquivos Lojas" / nome_arquivo
email.Attachments.Add(str(caminho_arquivo))
nome_arquivo = f"Ranking Lojas no Ano.xlsx"
caminho_arquivo = caminho_padrao / "Backup Arquivos Lojas" / nome_arquivo
email.Attachments.Add(str(caminho_arquivo))

# Corpo
email.HtmlBody = f'''
<p>Prezados,</p>
<br>
<p>Segue em anexo o ranking das lojas do dia {dia_data_maxima}/{mes_data_maxima}
<br>
<p>A melhor loja do dia foi: {melhor_loja_dia} com R$ {maior_faturamento_loja_dia:.2f}</p>
<p>A pior loja do dia foi: {pior_loja_dia} com R$ {menor_faturamento_loja_dia:.2f}</p>
<br>
<p>No ano, a melhor loja é {melhor_loja_ano} com faturamento acumulado de R$ {maior_faturamento_loja_ano:.2f}</p>
<p>E a pior foi: {pior_loja_dia} com com faturamento acumulado de R$ {menor_faturamento_loja_ano:.2f}</p>
<br>
<p>Qualquer dúvida, estou à disposição</p>
<p>Att, Lucas Galvão</p>
'''

# Enviar
email.Send()
print(f"Email da Diretoria enviado com sucesso")
# Out:
# lsgalvao1000+diretoria@gmail.com
# Email da Diretoria enviado com sucesso
